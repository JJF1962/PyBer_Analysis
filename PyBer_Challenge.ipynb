# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %%
ride_data_df['date'] = pd.to_datetime(ride_data_df['date'])

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                date   fare       ride_id  driver_count  \
# 0  Lake Jonathanshire 2019-01-14 10:14:00  13.83  5.739410e+12             5
# 1  South Michelleport 2019-03-04 18:24:00  30.24  2.343910e+12            72
# 2  Port Samanthamouth 2019-02-24 04:29:00  33.44  2.005070e+12            57
# 3          Rodneyfort 2019-02-10 23:22:00  23.44  5.149250e+12            34
# 4          South Jack 2019-03-06 04:28:00  34.58  3.908450e+12            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
type_rides_count = pyber_data_df.groupby(["type"]).count()["ride_id"]
type_rides_count
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
total_driversxtype = city_data_df.groupby(["type"]).sum()["driver_count"]
total_driversxtype.head()
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
total_faresxtype = pyber_data_df.groupby(["type"]).sum()["fare"]
total_faresxtype.head()
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
avg_rides_by_type = total_faresxtype / type_rides_count
avg_rides_by_type
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
avg_farexdriver = total_faresxtype  / total_driversxtype 
avg_farexdriver.head()
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_summary = pd.DataFrame(
    { "Total Rides": type_rides_count,
      "Total Drivers": total_driversxtype,
      "Total Fares": total_faresxtype,
      "Average Fare per Ride": avg_rides_by_type,
      "Average Fare per Driver": avg_farexdriver})
pyber_summary.head()
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary.index.name = None
pyber_summary.head()
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  8. Format the columns.
format_mapping = {"Total Drivers": '{:,}', "Total Fares": "{:,.0f}", "Average Fare per Ride": '${:,.2f}', "Average Fare per Driver": '${:,.2f}'}
pyber_summary.style.format(format_mapping)
# Out:
# <style type="text/css">
# </style>
# <table id="T_29724_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Rides</th>
#       <th class="col_heading level0 col1" >Total Drivers</th>
#       <th class="col_heading level0 col2" >Total Fares</th>
#       <th class="col_heading level0 col3" >Average Fare per Ride</th>
#       <th class="col_heading level0 col4" >Average Fare per Driver</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29724_level0_row0" class="row_heading level0 row0" >Rural</th>
#       <td id="T_29724_row0_col0" class="data row0 col0" >125</td>
#       <td id="T_29724_row0_col1" class="data row0 col1" >78</td>
#       <td id="T_29724_row0_col2" class="data row0 col2" >4,328</td>
#       <td id="T_29724_row0_col3" class="data row0 col3" >$34.62</td>
#       <td id="T_29724_row0_col4" class="data row0 col4" >$55.49</td>
#     </tr>
#     <tr>
#       <th id="T_29724_level0_row1" class="row_heading level0 row1" >Suburban</th>
#       <td id="T_29724_row1_col0" class="data row1 col0" >625</td>
#       <td id="T_29724_row1_col1" class="data row1 col1" >490</td>
#       <td id="T_29724_row1_col2" class="data row1 col2" >19,356</td>
#       <td id="T_29724_row1_col3" class="data row1 col3" >$30.97</td>
#       <td id="T_29724_row1_col4" class="data row1 col4" >$39.50</td>
#     </tr>
#     <tr>
#       <th id="T_29724_level0_row2" class="row_heading level0 row2" >Urban</th>
#       <td id="T_29724_row2_col0" class="data row2 col0" >1625</td>
#       <td id="T_29724_row2_col1" class="data row2 col1" >2,405</td>
#       <td id="T_29724_row2_col2" class="data row2 col2" >39,854</td>
#       <td id="T_29724_row2_col3" class="data row2 col3" >$24.53</td>
#       <td id="T_29724_row2_col4" class="data row2 col4" >$16.57</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df.head(10)
# Out:
#                  city                date   fare       ride_id  driver_count  \
# 0  Lake Jonathanshire 2019-01-14 10:14:00  13.83  5.739410e+12             5
# 1  South Michelleport 2019-03-04 18:24:00  30.24  2.343910e+12            72
# 2  Port Samanthamouth 2019-02-24 04:29:00  33.44  2.005070e+12            57
# 3          Rodneyfort 2019-02-10 23:22:00  23.44  5.149250e+12            34
# 4          South Jack 2019-03-06 04:28:00  34.58  3.908450e+12            46
# 5        South Latoya 2019-03-11 12:26:00   9.52  1.995000e+12            10
# 6       New Paulville 2019-02-27 11:17:00  43.25  7.932080e+11            44
# 7        Simpsonburgh 2019-04-26 00:43:00  35.98  1.119540e+11            21
# 8     South Karenland 2019-01-08 03:28:00  35.09  7.995620e+12             4
# 9       North Jasmine 2019-03-09 06:26:00  42.81  5.327640e+12            33
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban
# 5  Urban
# 6  Urban
# 7  Urban
# 8  Urban
# 9  Urban

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
daily_farextype = pyber_data_df.groupby(['type', 'date']).sum()[['fare']]
daily_farextype
# Out:
#                             fare
# type  date
# Rural 2019-01-01 09:45:00  43.69
#       2019-01-02 11:18:00  52.12
#       2019-01-03 19:51:00  19.90
#       2019-01-04 03:31:00  24.88
#       2019-01-06 07:38:00  47.33
# ...                          ...
# Urban 2019-05-08 04:20:00  21.99
#       2019-05-08 04:39:00  18.45
#       2019-05-08 07:29:00  18.55
#       2019-05-08 11:38:00  19.77
#       2019-05-08 13:10:00  18.04
#
# [2364 rows x 1 columns]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
daily_farextype = daily_farextype.reset_index()
daily_farextype.head()
# Out:
#     type                date   fare
# 0  Rural 2019-01-01 09:45:00  43.69
# 1  Rural 2019-01-02 11:18:00  52.12
# 2  Rural 2019-01-03 19:51:00  19.90
# 3  Rural 2019-01-04 03:31:00  24.88
# 4  Rural 2019-01-06 07:38:00  47.33

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares in each road for each type of city by the date. 
daily_farextype_pivot = daily_farextype.pivot(index ='date', columns ='type', values = 'fare')
daily_farextype_pivot.head()
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:00    NaN       NaN  37.91
# 2019-01-01 00:46:00    NaN     47.74    NaN
# 2019-01-01 02:07:00    NaN     24.07    NaN
# 2019-01-01 03:46:00    NaN       NaN   7.57
# 2019-01-01 05:23:00    NaN       NaN  10.75

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.

slice_daily_farextype_pivot = daily_farextype_pivot.loc['1/1/2019':'4/28/2019']
slice_daily_farextype_pivot.head(20)
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:00    NaN       NaN  37.91
# 2019-01-01 00:46:00    NaN     47.74    NaN
# 2019-01-01 02:07:00    NaN     24.07    NaN
# 2019-01-01 03:46:00    NaN       NaN   7.57
# 2019-01-01 05:23:00    NaN       NaN  10.75
# 2019-01-01 09:45:00  43.69       NaN    NaN
# 2019-01-01 12:32:00    NaN     25.56    NaN
# 2019-01-01 14:40:00    NaN       NaN   5.42
# 2019-01-01 14:42:00    NaN       NaN  12.31
# 2019-01-01 14:52:00    NaN     31.15    NaN
# 2019-01-01 17:22:00    NaN       NaN  42.11
# 2019-01-01 21:04:00    NaN       NaN  11.71
# 2019-01-02 00:13:00    NaN     44.71    NaN
# 2019-01-02 00:44:00    NaN       NaN  43.72
# 2019-01-02 00:56:00    NaN       NaN  37.34
# 2019-01-02 01:41:00    NaN     49.95    NaN
# 2019-01-02 01:46:00    NaN       NaN  34.79
# 2019-01-02 06:55:00    NaN       NaN  16.96
# 2019-01-02 07:26:00    NaN     33.57    NaN
# 2019-01-02 09:28:00    NaN       NaN  19.81

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
slice_daily_farextype_pivot.index = pd.to_datetime(slice_daily_farextype_pivot.index)
slice_daily_farextype_pivot
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:00    NaN       NaN  37.91
# 2019-01-01 00:46:00    NaN     47.74    NaN
# 2019-01-01 02:07:00    NaN     24.07    NaN
# 2019-01-01 03:46:00    NaN       NaN   7.57
# 2019-01-01 05:23:00    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-28 14:28:00    NaN       NaN  11.46
# 2019-04-28 16:29:00    NaN       NaN  36.42
# 2019-04-28 17:26:00    NaN       NaN  31.43
# 2019-04-28 17:38:00    NaN     34.87    NaN
# 2019-04-28 19:35:00    NaN     16.96    NaN
#
# [2182 rows x 3 columns]

# %%
# 7. Check that the datatype for the index is datetime using df.info()
slice_daily_farextype_pivot.info()
slice_daily_farextype_pivot.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2182 entries, 2019-01-01 00:08:00 to 2019-04-28 19:35:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     114 non-null    float64
#  1   Suburban  570 non-null    float64
#  2   Urban     1501 non-null   float64
# dtypes: float64(3)
# memory usage: 68.2 KB
# type                 Rural  Suburban  Urban
# date
# 2019-04-28 14:28:00    NaN       NaN  11.46
# 2019-04-28 16:29:00    NaN       NaN  36.42
# 2019-04-28 17:26:00    NaN       NaN  31.43
# 2019-04-28 17:38:00    NaN     34.87    NaN
# 2019-04-28 19:35:00    NaN     16.96    NaN

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
JanMay_weekly_farextype = slice_daily_farextype_pivot.resample('W').sum()
JanMay_weekly_farextype.head(15)
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  501.24   1010.73  2356.70
# 2019-04-14  269.79    784.82  2390.72

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

ax = JanMay_weekly_farextype.plot(figsize=(20,6))

ax.set_title('Weekly Fares by City Type')
plt.xlabel('Month')
plt.ylabel('Fare ($USD)')
#plt.subplots_adjust(bottom=0.15)
plt.show()
